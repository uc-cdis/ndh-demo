# %% [markdown]
# ## Visualization of AMR generated by Ariba and Mykrobe

# %%
Sys.setenv(TAR = "/bin/tar")
install.packages("IRkernel", dependencies = TRUE)
library(IRkernel)
install.packages('IRdisplay', dependencies = TRUE)
library('IRdisplay')
#install.packages(c('tidyverse',"Rcpp"))
#install.packages('dplyr', dependencies = TRUE)
#library(dplyr)
install.packages("htmlwidgets")
install.packages("ggplot2")
install.packages('pheatmap')
install.packages("devtools")
library(devtools)
install_github("hrbrmstr/waffle")
library(ggplot2)
library(waffle)
library(htmlwidgets)
library(pheatmap)
library(grid)
library(gridExtra)
# Out:
# also installing the dependencies ‘pkgbuild’, ‘rlang’, ‘brew’, ‘commonmark’, ‘pkgload’, ‘purrr’, ‘roxygen2’
#   There are binary versions available but the source versions are later:
#          binary source needs_compilation
# pkgbuild  1.0.3  1.0.6             FALSE
# rlang     0.3.1  0.4.2              TRUE
# purrr     0.3.2  0.3.3              TRUE
# roxygen2  6.1.1  7.0.1              TRUE
# IRkernel 0.8.15  1.0.2             FALSE
#
#
# The downloaded binary packages are in
# 	/var/folders/nn/5b6spj6n7bn9jg_myzn59k300000gn/T//RtmpFOGQQ3/downloaded_packages
# installing the source packages ‘pkgbuild’, ‘rlang’, ‘purrr’, ‘roxygen2’, ‘IRkernel’
#
# Warning message in init_backup_env():
# “init_backup_env called a second time after init_shadowenv:
# 36: fun(libname, pkgname)
# 35: doTryCatch(return(expr), name, parentenv, handler)
# 34: tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 33: tryCatchList(expr, classes, parentenv, handlers)
# ...

# %%
source('NIAID_plots.r')
# Out:
# Warning message:
# “package ‘devtools’ was built under R version 3.4.4”Warning message:
# “package ‘ggplot2’ was built under R version 3.4.4”Warning message:
# “As of rlang 0.4.0, dplyr must be at least version 0.8.0.
# ✖ dplyr 0.7.6 is too old for rlang 0.4.2.
# ℹ Please update dplyr with `install.packages("dplyr")`.”Warning message:
# “package ‘htmlwidgets’ was built under R version 3.4.4”

# %% [markdown]
# ### Phylogenetic tree using clustering method based on match information on clusters created by Ariba

# %%
IRdisplay::display_javascript('IPython.OutputArea.auto_scroll_threshold = 99999;')
options(repr.plot.res=800,repr.plot.width=6, repr.plot.height=4.5)
heat_map()

# %% [markdown]
# ### Comparison of performances of 2 AMR prediction methods (Ariba and Mykrobe) based on both specificity and sensitivity

# %%
IRdisplay::display_javascript('IPython.OutputArea.auto_scroll_threshold = 99999;')
options(repr.plot.res=800,repr.plot.width=6, repr.plot.height=4.5)
scatter_plot()

# %% [markdown]
# ### Accuracy comparison between Ariba and Mykrobe

# %%
IRdisplay::display_javascript('IPython.OutputArea.auto_scroll_threshold = 99999;')
options(repr.plot.res=800,repr.plot.width=6, repr.plot.height=4.5)
grid_plot()

# %%
IRdisplay::display_javascript('IPython.OutputArea.auto_scroll_threshold = 99999;')
options(repr.plot.res=800,repr.plot.width=6, repr.plot.height=4.3)
sorted_grid()
