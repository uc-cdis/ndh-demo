# %% [markdown]
# # NIAID DATA HUB: DMID-LHV Data Analysis

# %% [markdown]
# ### Get summary metrics for each data type in the data model:

# %%
# %matplotlib inline
import nde_dmid_function as nde
nde.add_keys("/home/jovyan/pd/credentials.json")

# %%
nde.query_summary_counts('FLU-LHV',nde.summary_order_LHV,nde.summary_count_headers_LHV)
# Out:
# <table style><thead><th>Category</th><th>Counts</th></thead><tr><td>Studies</td><td>12</td><tr><tr><td>Subjects</td><td>321</td><tr><tr><td>Demographic records</td><td>321</td><tr><tr><td>Exposure records</td><td>241</td><tr><tr><td>Followup records</td><td>1092</td><tr><tr><td>Sample records</td><td>931</td><tr><tr><td>Virus Infection records</td><td>709</td><tr><tr><td>Lab Results records</td><td>517</td><tr><tr><td>Aliquots</td><td>2609</td><tr><tr><td>mRNA Microarray</td><td>694</td><tr><tr><td>mRNA Expression</td><td>13</td><tr><tr><td>Protein Mass Spectrometry</td><td>496</td><tr><tr><td>Peptide Expression</td><td>9</td><tr><tr><td>Protein Expression</td><td>10</td><tr><tr><td>Lipid Mass Spectrometry</td><td>572</td><tr><tr><td>Metabolite Mass Spectrometry</td><td>459</td><tr></table>

# %% [markdown]
# ### DMID-LHV Scientific User Cases

# %% [markdown]
# The following part of the demo is focused on answering some specific scientific questions based on the data currently available at the NIAID Data Hub

# %% [markdown]
# #### Scientific User Case 1.1: Plot virus titer in different time points post virus infection

# %% [markdown]
# #### Plot virus titer for studies ICL004, ECL001,ECL005 and ICL006

# %%
nde.plot_cell_titer(["ICL004","ECL001","SCL005","ICL006"])

# %% [markdown]
# #### Plot virus titer for individual study

# %%
nde.plot_cell_titer(["ICL102"])

# %%
nde.plot_cell_titer(["ICL103"])

# %%
nde.plot_cell_titer(["ICL104"])

# %%
nde.plot_cell_titer(["ICL011"])

# %%
nde.plot_cell_titer(["ECL001"])

# %%
nde.plot_mouse_titer("IM101")

# %%
nde.plot_mouse_titer("IM102")

# %%
nde.plot_mouse_titer("IM103")

# %% [markdown]
# #### Scientific User Case 1.2: Plot viral genomic RNA in different time points post virus infection

# %% [markdown]
# #### Plot genomic RNA quantification for studies ICL004, ICL006 and SCL005

# %%
nde.plot_gRNA(["ICL004","ICL006","SCL005"])

# %% [markdown]
# #### Plot genomic RNA quantification for individual study

# %%
nde.plot_gRNA(["ICL004"])

# %%
nde.plot_gRNA(["ICL006"])

# %%
nde.plot_gRNA(["ICL012"])

# %%
nde.plot_gRNA(["SCL005"])

# %% [markdown]
# #### Scientific User Case 1.3: Plot mouse weight percentage in relative to day0 in different time points post virus infection

# %%
nde.plot_weight_percentage('IM101')

# %%
nde.plot_weight_percentage('IM102')

# %%
nde.plot_weight_percentage('IM103')
